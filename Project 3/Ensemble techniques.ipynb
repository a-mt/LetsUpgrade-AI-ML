# %% [markdown]
# 1. Import packages, read data & explore
# 2. Perform EDA
#    - Handle missing data
#    - 5 point summary
#    - Detect & solve outliers
#    - Check data distribution, is it balanced
#    - Get correlation value
#    - Label encoding
#    - Change data type
#    - Remove columns
#    - Pairplot
#    - Scale data (StandardScaler or z_score)
# 3. Split data (70:30)
# 4. Model building
#    - Logistic Regression
#    - Naive Bayes
#    - KNN
#    - SVC
#    - Decision tree
#        - Feature importance test for DT
#        - Prunning DT
# 5. Ensemble models
#    - Bagging
#    - Adaptive Boosting
#    - Gradient boosting
#    - Random Forest
# 7. Models with accuracy scores
# 8. Conclusion
#    - comments on dataset
#    - on models
#    - miscellaneous

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# In /home/myself/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/myself/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/myself/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/myself/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/myself/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/myself/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/myself/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/myself/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# /home/myself/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from scipy.stats import pearsonr
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, \
                                  MinMaxScaler, \
                                  RobustScaler, \
                                  LabelEncoder

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %%
from IPython.display import Image
from os import system
from sklearn.tree import export_graphviz
#from sklearn.externals.six import StringIO
#import pydotplus
#import graphviz

# %%
from sklearn.ensemble import BaggingClassifier, \
                             AdaBoostClassifier, \
                             GradientBoostingClassifier, \
                             RandomForestClassifier

# %%
from statistics import median,mean
from sklearn.metrics import accuracy_score, \
                            confusion_matrix, \
                            classification_report, \
                            roc_auc_score, \
                            precision_score, \
                            recall_score

# %% [markdown]
# ## Import data

# %%
df = pd.read_csv('bank-full.csv')
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome Target
# 0  unknown    5   may       261         1     -1         0  unknown     no
# 1  unknown    5   may       151         1     -1         0  unknown     no
# 2  unknown    5   may        76         1     -1         0  unknown     no
# 3  unknown    5   may        92         1     -1         0  unknown     no
# 4  unknown    5   may       198         1     -1         0  unknown     no

# %%
df.shape
# Out:
# (45211, 17)

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# Target       object
# dtype: object

# %% [markdown]
# ## EDA
#
# ### Check categories

# %%
for col in df.select_dtypes('object'):
    print(df[col].value_counts())
    print('')
# Out:
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: job, dtype: int64
#
# married     27214
# single      12790
# divorced     5207
# Name: marital, dtype: int64
#
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: education, dtype: int64
#
# no     44396
# yes      815
# Name: default, dtype: int64
#
# yes    25130
# no     20081
# Name: housing, dtype: int64
#
# no     37967
# yes     7244
# Name: loan, dtype: int64
#
# cellular     29285
# unknown      13020
# telephone     2906
# Name: contact, dtype: int64
#
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: month, dtype: int64
#
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: poutcome, dtype: int64
#
# no     39922
# yes     5289
# Name: Target, dtype: int64

# %%
cols = df.select_dtypes('object').columns
cols
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'Target'],
#       dtype='object')

# %%
df[cols] = df[cols].apply(pd.Categorical)
df.dtypes
# Out:
# age             int64
# job          category
# marital      category
# education    category
# default      category
# balance         int64
# housing      category
# loan         category
# contact      category
# day             int64
# month        category
# duration        int64
# campaign        int64
# pdays           int64
# previous        int64
# poutcome     category
# Target       category
# dtype: object

# %% [markdown]
# ### Check missing values

# %%
df.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# Target       0
# dtype: int64

# %% [markdown]
# ### Check distribution of nummerical features
#
# #### 5 point summary

# %%
df.describe().T
# Out:
#             count         mean          std     min    25%    50%     75%  \
# age       45211.0    40.936210    10.618762    18.0   33.0   39.0    48.0
# balance   45211.0  1362.272058  3044.765829 -8019.0   72.0  448.0  1428.0
# day       45211.0    15.806419     8.322476     1.0    8.0   16.0    21.0
# duration  45211.0   258.163080   257.527812     0.0  103.0  180.0   319.0
# campaign  45211.0     2.763841     3.098021     1.0    1.0    2.0     3.0
# pdays     45211.0    40.197828   100.128746    -1.0   -1.0   -1.0    -1.0
# previous  45211.0     0.580323     2.303441     0.0    0.0    0.0     0.0
#
#                max
# age           95.0
# balance   102127.0
# day           31.0
# duration    4918.0
# campaign      63.0
# pdays        871.0
# previous     275.0

# %% [markdown]
# Comparing the min/max with mean+std, we see that age has outliers.
#
# &mu;    = 40
# &sigma; = 10
# &mu;+3&sigma; = 70
# max = 95
#
# In also the case in balance, duration, campaign, pdays, previous — so all of them except day.
#
# #### displot

# %%
df.select_dtypes(exclude=['category']).columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
fig, ax = plt.subplots(nrows=4, ncols=2, figsize=(10,15))
ax = ax.flatten()
i  = 0

for col in df.select_dtypes('int64').columns:
    sns.distplot(df[col], ax=ax[i])
    i += 1

ax.flat[-1].set_visible(False)

# %% [markdown]
# #### skewness

# %%
df.skew()
# Out:
# age          0.684818
# balance      8.360308
# day          0.093079
# duration     3.144318
# campaign     4.898650
# pdays        2.615715
# previous    41.846454
# dtype: float64

# %% [markdown]
# #### boxplot

# %%
fig, ax = plt.subplots(nrows=4, ncols=2, figsize=(10,15))
ax = ax.flatten()
i  = 0

for col in df.select_dtypes('int64').columns:
    sns.boxplot(df[col], ax=ax[i])
    i += 1

ax.flat[-1].set_visible(False)

# %% [markdown]
# ### Check distribution of categorical feature

# %%
fig, ax = plt.subplots(nrows=5, ncols=2, figsize=(10,15))
ax = ax.flatten()
i  = 0

for col in df.select_dtypes('category').columns:
    sns.countplot(x=df[col], data=df, ax=ax[i])

    if i==0:
        ax[i].tick_params(rotation=90, axis='x')
    i += 1

fig.tight_layout()

# %% [markdown]
# Most customers have been contacted in may, with their cellular number
# Most people have a house loan
# Around 6% of customers have credit in default

# %% [markdown]
# ### Label Encoding

# %%
df2     = df.copy()
cols    = df.select_dtypes('category').columns
encoder = LabelEncoder()

for col in cols:
    df2[col] = encoder.fit_transform(df[col]).astype(int)

df2[cols] = df2[cols].apply(pd.Categorical)
df2.head()
# Out:
#    age job marital education default  balance housing loan contact  day month  \
# 0   58   4       1         2       0     2143       1    0       2    5     8
# 1   44   9       2         1       0       29       1    0       2    5     8
# 2   33   2       1         1       0        2       1    1       2    5     8
# 3   47   1       1         3       0     1506       1    0       2    5     8
# 4   33  11       2         3       0        1       0    0       2    5     8
#
#    duration  campaign  pdays  previous poutcome Target
# 0       261         1     -1         0        3      0
# 1       151         1     -1         0        3      0
# 2        76         1     -1         0        3      0
# 3        92         1     -1         0        3      0
# 4       198         1     -1         0        3      0

# %%
df2.dtypes
# Out:
# age             int64
# job          category
# marital      category
# education    category
# default      category
# balance         int64
# housing      category
# loan         category
# contact      category
# day             int64
# month        category
# duration        int64
# campaign        int64
# pdays           int64
# previous        int64
# poutcome     category
# Target       category
# dtype: object

# %% [markdown]
# ### Handle outliers
#
# We will use mean replacement

# %%
# Replace outliers > Q3 with mean
cols = ['age', 'balance', 'duration', 'campaign', 'pdays', 'previous']

for col in cols:
    mean = df2[col].mean()
    Q3   = np.percentile(df2[col], 75)

    df2[col] = np.where(df2[col] > Q3, mean, df2[col])

# %%
fig, ax = plt.subplots(nrows=4, ncols=2, figsize=(10,15))
ax = ax.flatten()
i  = 0

for col in cols:
    sns.boxplot(df2[col], ax=ax[i])
    i += 1

ax.flat[-1].set_visible(False)

# %% [markdown]
# ### Plot correlation

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True, vmax=1, vmin=-1)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df2.corr(), annot=True, vmax=1, vmin=-1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Remove columns

# %%
df2.drop(['job', 'education', 'contact', \
          'duration', 'pdays', 'day', 'month'], axis=1, inplace=True)
df2.head()
# Out:
#         age marital default      balance housing loan  campaign  previous  \
# 0  40.93621       1       0  1362.272058       1    0       1.0       0.0
# 1  44.00000       2       0    29.000000       1    0       1.0       0.0
# 2  33.00000       1       0     2.000000       1    1       1.0       0.0
# 3  47.00000       1       0  1362.272058       1    0       1.0       0.0
# 4  33.00000       2       0     1.000000       0    0       1.0       0.0
#
#   poutcome Target
# 0        3      0
# 1        3      0
# 2        3      0
# 3        3      0
# 4        3      0

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(df2)

# %% [markdown]
# ---
#
# ## Split data

# %%
X = df2.drop('Target', axis=1)
y = df2['Target']

print(X.shape)
print(y.shape)
# Out:
# (45211, 9)
# (45211,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=2)

print(X_train.shape)
print(y_train.shape)
# Out:
# (31647, 9)
# (31647,)

# %% [markdown]
# ## Scale data

# %%
scaler   = StandardScaler()
X_train2 = scaler.fit_transform(X_train)
X_test2  = scaler.transform(X_test)

# %% [markdown]
# ## Build model
#
# ### Logistic Regression Model

# %%
logic_r = LogisticRegression(solver='liblinear')
logic_r.fit(X_train2, y_train)

# %%
y_pred = logic_r.predict(X_test2)

# %%
# Out:
# Confusion Matrix
#  [[11885   114]
#  [ 1318   247]]

# %%
logic_r_accuracy = accuracy_score(y_test, y_pred)

print('Confusion Matrix\n', confusion_matrix(y_test, y_pred), '\n')
print('Accuracy Score\n', logic_r_accuracy, '\n')
print('Classification Report\n', classification_report(y_test, y_pred))
# Out:
# Confusion Matrix
#  [[11885   114]
#  [ 1318   247]]
#
# Accuracy Score
#  0.894426422884105
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94     11999
#            1       0.68      0.16      0.26      1565
#
#     accuracy                           0.89     13564
#    macro avg       0.79      0.57      0.60     13564
# weighted avg       0.88      0.89      0.86     13564

# %% [markdown]
# ### Naive Bayes

# %%
NB = GaussianNB()
NB.fit(X_train2, y_train)

# %%
y_pred = NB.predict(X_test2)

# %%
nb_accuracy = accuracy_score(y_test, y_pred)

print('Confusion Matrix\n', confusion_matrix(y_test, y_pred), '\n')
print('Accuracy Score\n', nb_accuracy, '\n')
print('Classification Report\n', classification_report(y_test, y_pred), '\n')
# Out:
# Confusion Matrix
#  [[10687  1312]
#  [ 1082   483]]
#
# Accuracy Score
#  0.8235033913299912
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90     11999
#            1       0.27      0.31      0.29      1565
#
#     accuracy                           0.82     13564
#    macro avg       0.59      0.60      0.59     13564
# weighted avg       0.83      0.82      0.83     13564

# %% [markdown]
# ### KNN

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train2, y_train)

# %%
y_pred = knn.predict(X_test2)

# %%
knn_accuracy = accuracy_score(y_test, y_pred)

print('Confusion Matrix\n', confusion_matrix(y_test, y_pred), '\n')
print('Accuracy Score\n', knn_accuracy, '\n')
print('Classification Report\n', classification_report(y_test, y_pred), '\n')
# Out:
# Confusion Matrix
#  [[11435   564]
#  [ 1243   322]]
#
# Accuracy Score
#  0.8667797109997051
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93     11999
#            1       0.36      0.21      0.26      1565
#
#     accuracy                           0.87     13564
#    macro avg       0.63      0.58      0.59     13564
# weighted avg       0.84      0.87      0.85     13564

# %% [markdown]
# ### SVC

# %%
svc = SVC()
svc.fit(X_train2, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = svc.predict(X_test2)

# %%
svc_accuracy = accuracy_score(y_test, y_pred)

print('Confusion Matrix\n', confusion_matrix(y_test, y_pred), '\n')
print('Accuracy Score\n', svc_accuracy, '\n')
print('Classification Report\n', classification_report(y_test, y_pred), '\n')
# Out:
# Confusion Matrix
#  [[11856   143]
#  [ 1284   281]]
#
# Accuracy Score
#  0.8947950457092303
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94     11999
#            1       0.66      0.18      0.28      1565
#
#     accuracy                           0.89     13564
#    macro avg       0.78      0.58      0.61     13564
# weighted avg       0.87      0.89      0.87     13564

# %% [markdown]
# ### Decision Tree

# %%
dt = DecisionTreeClassifier(criterion='gini')
dt.fit(X_train2, y_train)

# %%
y_pred = dt.predict(X_test2)

# %%
dt_accuracy = accuracy_score(y_test, y_pred)

print('Confusion Matrix\n', confusion_matrix(y_test, y_pred), '\n')
print('Accuracy Score\n', dt_accuracy, '\n')
print('Classification Report\n', classification_report(y_test, y_pred), '\n')
# Out:
# Confusion Matrix
#  [[11091   908]
#  [ 1241   324]]
#
# Accuracy Score
#  0.8415659097611324
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91     11999
#            1       0.26      0.21      0.23      1565
#
#     accuracy                           0.84     13564
#    macro avg       0.58      0.57      0.57     13564
# weighted avg       0.83      0.84      0.83     13564

# %% [markdown]
# #### Feature importance test

# %%
dt.feature_importances_
# Out:
# array([0.20704384, 0.05066561, 0.00515358, 0.48852109, 0.02411437,
#        0.02600765, 0.06465889, 0.03743262, 0.09640235])

# %%
dt.feature_importances_.shape
# Out:
# (9,)

# %%
X_train.columns.shape
# Out:
# (9,)

# %%
pd.Series(
    data=dt.feature_importances_,
    index=X_train.columns
).sort_values(ascending=False)
# Out:
# balance     0.488521
# age         0.207044
# poutcome    0.096402
# campaign    0.064659
# marital     0.050666
# previous    0.037433
# loan        0.026008
# housing     0.024114
# default     0.005154
# dtype: float64

# %% [markdown]
# ---
#
# ## Ensemble techniques
#
# ### Bagging

# %%
bag = BaggingClassifier(base_estimator=dt, n_estimators=500)
bag.fit(X_train2, y_train)

# %%
y_pred = bag.predict(X_test2)

# %%
bag_accuracy = accuracy_score(y_test, y_pred)

print('Confusion Matrix\n', confusion_matrix(y_test, y_pred), '\n')
print('Accuracy Score\n', bag_accuracy, '\n')
print('Classification Report\n', classification_report(y_test, y_pred), '\n')
# Out:
# Confusion Matrix
#  [[11613   386]
#  [ 1275   290]]
#
# Accuracy Score
#  0.8775434974933648
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93     11999
#            1       0.43      0.19      0.26      1565
#
#     accuracy                           0.88     13564
#    macro avg       0.67      0.58      0.60     13564
# weighted avg       0.85      0.88      0.86     13564

# %% [markdown]
# ### AdaBoosting

# %%
ada = AdaBoostClassifier(n_estimators=50)
ada.fit(X_train2, y_train)

# %%
y_pred = ada.predict(X_test2)

# %%
ada_accuracy = accuracy_score(y_test, y_pred)

print('Confusion Matrix\n', confusion_matrix(y_test, y_pred), '\n')
print('Accuracy Score\n', ada_accuracy, '\n')
print('Classification Report\n', classification_report(y_test, y_pred), '\n')
# Out:
# Confusion Matrix
#  [[11886   113]
#  [ 1320   245]]
#
# Accuracy Score
#  0.8943526983190799
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94     11999
#            1       0.68      0.16      0.25      1565
#
#     accuracy                           0.89     13564
#    macro avg       0.79      0.57      0.60     13564
# weighted avg       0.88      0.89      0.86     13564

# %% [markdown]
# ### Random Forest

# %%
rf = RandomForestClassifier(n_estimators=100, max_features=3)
rf.fit(X_train2, y_train)

# %%
y_pred = rf.predict(X_test2)

# %%
rf_accuracy = accuracy_score(y_test, y_pred)

print('Confusion Matrix\n', confusion_matrix(y_test, y_pred), '\n')
print('Accuracy Score\n', rf_accuracy, '\n')
print('Classification Report\n', classification_report(y_test, y_pred), '\n')
# Out:
# Confusion Matrix
#  [[11510   489]
#  [ 1249   316]]
#
# Accuracy Score
#  0.8718667059864347
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93     11999
#            1       0.39      0.20      0.27      1565
#
#     accuracy                           0.87     13564
#    macro avg       0.65      0.58      0.60     13564
# weighted avg       0.84      0.87      0.85     13564

# %% [markdown]
# ### Gradient Boosting

# %%
grad = GradientBoostingClassifier(n_estimators=100)
grad.fit(X_train2, y_train)

# %%
y_pred = grad.predict(X_test2)

# %%
grad_accuracy = accuracy_score(y_test, y_pred)

print('Confusion Matrix\n', confusion_matrix(y_test, y_pred), '\n')
print('Accuracy Score\n', grad_accuracy, '\n')
print('Classification Report\n', classification_report(y_test, y_pred), '\n')
# Out:
# Confusion Matrix
#  [[11867   132]
#  [ 1293   272]]
#
# Accuracy Score
#  0.8949424948392805
#
# Classification Report
#                precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94     11999
#            1       0.67      0.17      0.28      1565
#
#     accuracy                           0.89     13564
#    macro avg       0.79      0.58      0.61     13564
# weighted avg       0.88      0.89      0.87     13564

# %% [markdown]
# ## Compare scores

# %%
scores = [
    ('Naive bayes', nb_accuracy),
    ('KNN', knn_accuracy),
    ('Logistic reg', logic_r_accuracy),
    ('SVC', svc_accuracy),
    ('Decision tree', dt_accuracy),
    ('Bagging', bag_accuracy),
    ('Adaptive boosting', ada_accuracy),
    ('Random forest', rf_accuracy),
    ('Gradient boosting', grad_accuracy)
]
pd.DataFrame(scores, columns=['Model','Accuracy score']) \
  .sort_values(by='Accuracy score', ascending=False)
# Out:
#                Model  Accuracy score
# 8  Gradient boosting        0.894942
# 3                SVC        0.894795
# 2       Logistic reg        0.894426
# 6  Adaptive boosting        0.894353
# 5            Bagging        0.877543
# 7      Random forest        0.871867
# 1                KNN        0.866780
# 4      Decision tree        0.841566
# 0        Naive bayes        0.823503

# %% [markdown]
# ## Conclusion
#
# 1. The models perform well at predicting the class 0
# 2. It does not perform well at predicting the class 1 (the recall & precision is low), because it doesn't have a lot of data
# 3. The ratio between class 0 and 1 is high. We could have better results is the dataset was balanced
